# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/Users/matthewdunn/Dropbox/CosmicAnalysis/Raw_Data.csv")

# %%
data[NT] = data[MutationCDS].str[1:]
splitDataRepository[splitname] = fileToBeSplitData.MutationCDS.str()
# Out:
#      Gene PositionAA           MutationCDS  MutationAA MutationIDCOSM  Count  \
# 0    TP53          ?            c.375+1G>A         p.?      COSM45304      1
# 1    TP53          ?           c.376-10C>T         p.?      COSM46116      1
# 2    TP53          ?            c.376-1G>A         p.?       COSM6900      1
# 3    TP53          ?            c.559+1G>C         p.?      COSM33648      3
# 4    TP53          ?            c.559+1G>T         p.?      COSM44268      1
# 5    TP53          ?            c.560-1G>A         p.?      COSM43753      1
# 6    TP53          ?            c.560-2A>T         p.?      COSM45026      1
# 7    TP53          ?            c.782+1G>A         p.?      COSM43571      1
# 8    TP53          ?            c.783-1G>A         p.?      COSM44604      6
# 9    TP53          ?            c.783-6G>A         p.?      COSM46381      1
# 10   TP53          ?  c.783-8_920-27del211         p.?      COSM13748      2
# ...

# %%
import re

txt='c.1020G>A'

re1='.*?'	# Non-greedy match on filler
re2='(\\d+)'	# Integer Number 1

rg = re.compile(re1+re2,re.IGNORECASE|re.DOTALL)
m = rg.search(txt)
if m:
    int1=m.group(1)
    print "("+int1+")"+"\n"

# %%
$txt='c.782+24C>G';

$re1='.*?';	# Non-greedy match on filler
$re2='(782)';	# Integer Number 1

$re=$re1.$re2;
if ($txt =~ m/$re/is)
{
    $int1=$1;
    print "($int1) \n";
}

# %%
if re.match(regex, content) is not None:
  blah..

# %%
import re
import sys

testinglists = ["c.881A>T","c.1-72C>G","c.742_743insGCT", ]

myre = '(\d{4})(?=\D{1})|(\d{3})(?=\D{1})|(\d{2})(?=\D{1})'

for x in testinglists:
    print re.search(myre,x).group(1)
# Out:
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-c71e6037492c> in <module>()
#       7
#       8 for x in testinglists:
# ----> 9     print re.search(myre,x).group(1)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
((\d{4})(?=\D{1})|(\d{3})(?=\D{1})|(\d{2})(?=\D{1}))|((\d{4})(?=\D{2})|(\d{3})(?=\D{2})|(\d{2})(?=\D{2}))
